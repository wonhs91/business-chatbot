# %%
print("hello")
# Out:
# hello

# %%
# %cd backend

from backend.app.agents.graph import AgentOrchestrator
from IPython.display import Image, display

agent_orchestrator = AgentOrchestrator()

display(Image(agent_orchestrator._graph.get_graph().draw_mermaid_png()))
# Out:
# [WinError 2] The system cannot find the file specified: 'backend'
# c:\Users\wonhs\projects\AI projects\business-chatbot\backend
